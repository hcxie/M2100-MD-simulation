# %%
import numpy as np
import pandas as pd
import math as math
import matplotlib.pyplot as plt
import seaborn as sns
import math as math
# %matplotlib inline

# %%
dist_df=pd.DataFrame(columns=["AA results","CG results"])

# %%
for i in range(0,16):
    filename="dist_c"+str(i+1)+"c"+str(i+2)+".txt"
    indexname="c"+str(i+1)+"c"+str(i+2)
    dist=np.loadtxt(filename, delimiter="\n", skiprows=1)   
    cdist=np.loadtxt("c"+filename, delimiter="\n", skiprows=1)
    dist_df.loc[indexname]=[dist,cdist]

# %%
dist_df.shape
# Out:
# (16, 2)

# %%
dist_df_par=pd.DataFrame(columns=["AA mean","AA std","AA K","CG mean","CG std","CG k"])

# %%
for i in range(0,16):
    filename="dist_c"+str(i+1)+"c"+str(i+2)+".txt"
    indexname="c"+str(i+1)+"c"+str(i+2)
    dist=np.loadtxt(filename, delimiter="\n", skiprows=1)   
    cdist=np.loadtxt("c"+filename, delimiter="\n", skiprows=1)
    aa_mean=np.mean(dist)
    aa_std=np.std(dist)
    aa_K=300/(2*aa_std**2)*1.38064852*(10**-23)/4184*(6.022*10**23)
    cg_mean=np.mean(cdist)
    cg_std=np.std(cdist)
    cg_K=300/(2*cg_std**2)*1.38064852*(10**-23)/4184*(6.022*10**23)
    dist_df_par.loc[indexname]=[aa_mean,aa_std,aa_K,cg_mean,cg_std,cg_K]

# %%
dist_df_par
# Out:
#          AA mean    AA std        AA K   CG mean    CG std         CG k
# c1c2    1.904512  0.036801  220.096985  1.903669  0.009468  3325.203381
# c2c3    3.585114  0.213901    6.514744  3.626880  0.222106     6.042282
# c3c4    3.577133  0.207585    6.917234  3.624779  0.206429     6.994910
# c4c5    3.445323  0.265384    4.232291  3.539967  0.284493     3.682813
# c5c6    3.545809  0.227580    5.755129  3.529571  0.234516     5.419748
# c6c7    3.356172  0.280722    3.782428  3.445159  0.288022     3.593129
# c7c8    3.757823  0.071435   58.412671  3.802412  0.078108    48.857303
# c8c9    2.947716  0.044913  147.765902  2.951242  0.032772   277.542366
# c9c10   2.950457  0.043625  156.619766  2.951295  0.032217   287.187726
# c10c11  3.762927  0.072716   56.371661  3.802581  0.078273    48.651471
# c11c12  3.383185  0.296050    3.400893  3.452535  0.308637     3.129168
# c12c13  3.494849  0.251479    4.713244  3.537605  0.262921     4.311950
# c13c14  3.559947  0.227022    5.783478  3.630242  0.235040     5.395622
# c14c15  3.548578  0.232309    5.523205  3.531851  0.240324     5.160945
# c15c16  3.547431  0.230809    5.595223  3.532674  0.236944     5.309238
# c16c17  1.904686  0.036524  223.449017  1.903593  0.008914  3750.912528

# %%
def compareplot(distdata,i):
    plt.figure(figsize = [5, 5])
    sns.distplot(distdata.iloc[i,0],bins=20,kde=True,hist_kws = {'alpha' : 0.1})
    sns.distplot(distdata.iloc[i,1],bins=20,kde=True,hist_kws = {'alpha' : 0.1})

for i in range(0,dist_df.shape[0]):
    compareplot(dist_df,i)
# Out:
# C:\Users\xhc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
angle_df=pd.DataFrame(columns=["AA results","CG results"])

# %%
for i in range(0,15):
    filename="angle_c"+str(i+1)+"c"+str(i+2)+"c"+str(i+3)+".txt"
    indexname="c"+str(i+1)+"c"+str(i+2)+"c"+str(i+3)
    angl=np.loadtxt(filename, delimiter="\n", skiprows=1)   
    cangl=np.loadtxt("c"+filename, delimiter="\n", skiprows=1)
    angle_df.loc[indexname]=[angl,cangl]

# %%
def compareplot(distdata,i):
    plt.figure(figsize = [5, 5])
    sns.distplot(distdata.iloc[i,0],bins=20,kde=True,hist_kws = {'alpha' : 0.1})
    sns.distplot(distdata.iloc[i,1],bins=20,kde=True,hist_kws = {'alpha' : 0.1})

for i in range(0,angle_df.shape[0]):
    compareplot(angle_df,i)

# %%
angl_df_par=pd.DataFrame(columns=["AA mean","AA std","AA K","CG mean","CG std","CG k"])

# %%
for i in range(0,15):
    filename="angle_c"+str(i+1)+"c"+str(i+2)+"c"+str(i+3)+".txt"
    indexname="c"+str(i+1)+"c"+str(i+2)+"c"+str(i+3)
    angl=np.loadtxt(filename, delimiter="\n", skiprows=1)   
    cangl=np.loadtxt("c"+filename, delimiter="\n", skiprows=1)
    aa_mean=np.mean(angl)/math.pi*180
    aa_std=np.std(angl)
    aa_K=300/(2*aa_std**2)*1.38064852*(10**-23)/4184*(6.022*10**23)
    cg_mean=np.mean(cangl)/math.pi*180
    cg_std=np.std(cangl)
    cg_K=300/(2*cg_std**2)*1.38064852*(10**-23)/4184*(6.022*10**23)
    angl_df_par.loc[indexname]=[aa_mean,aa_std,aa_K,cg_mean,cg_std,cg_K]

# %%
angl_df_par
# Out:
#               AA mean    AA std       AA K     CG mean    CG std       CG k
# c1c2c3     127.828813  0.265776   4.219797  123.742345  0.280006   3.801790
# c2c3c4     131.600103  0.368858   2.190808  124.321354  0.332417   2.697474
# c3c4c5     127.837740  0.397667   1.884883  119.997917  0.369272   2.185900
# c4c5c6     107.404353  0.379248   2.072418  103.781364  0.361711   2.278238
# c5c6c7     103.253932  0.341415   2.557169  100.619273  0.334941   2.656966
# c6c7c8     123.775673  0.412127   1.754936  115.668412  0.383503   2.026680
# c7c8c9     159.822107  0.066887  66.626301  159.014829  0.065488  69.502663
# c8c9c10    105.350256  0.096518  31.996656  105.111069  0.102070  28.610462
# c9c10c11   160.534718  0.069374  61.934399  159.583225  0.067011  66.379661
# c10c11c12  128.250714  0.322423   2.867289  121.567305  0.315190   3.000404
# c11c12c13  122.903950  0.374221   2.128471  115.550307  0.364543   2.242986
# c12c13c14  132.473060  0.380606   2.057655  121.685482  0.371115   2.164245
# c13c14c15  123.882343  0.373896   2.132165  117.101868  0.360543   2.293033
# c14c15c16  133.323783  0.416334   1.719648  121.180423  0.396578   1.895250
# c15c16c17  133.956050  0.254987   4.584453  129.724020  0.247020   4.884930
